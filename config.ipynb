# %%
import torch

class Config:
    MODEL_NAME = "bert-base-multilingual-cased"
    MAX_LEN = 64
    BATCH_SIZE = 16
    LR = 2e-5
    EPOCHS = 5

    NUM_DISEASE = 12
    NUM_ADVISORY = 8
    NUM_ENTITY = 4

    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

config = Config()
