# %%
from fastapi import FastAPI
from api.schema import Query
from models.full_model import AgroModel

app = FastAPI()
model = AgroModel()

@app.post("/predict")
def predict(q: Query):
    return {"response": f"Processed: {q.text}"}
